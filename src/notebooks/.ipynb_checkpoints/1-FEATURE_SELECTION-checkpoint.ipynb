# %% [markdown]
# <h1><center>General Info</center></h1>

# %% [markdown]
# This part covers basic feature selection pipeline implementation.
#
# **1)** Firstly, the data are split in startified manner `train_test_split` into train, validate and test
#
# **2)** Label and feature encoding with `LabelEncoder`, `ColumnTransformer` and `OneHotEncoder`
#
# **3)** `VarianceThreshold` was used as a first approach to filter our non-informative features
#
# **4)** Then `BorutaPy` via `BalancedRandomForestClassifier` selects the final feature set
#
# **5)** Export to `.parquet` is used for the final feauture set

# %% [markdown]
# ---

# %% [markdown]
# <h1><center>Imports</center></h1>

# %%
import os, sys, pickle

import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split  
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, LabelEncoder         
from sklearn.feature_selection import VarianceThreshold 

from imblearn.ensemble import BalancedRandomForestClassifier

from boruta import BorutaPy

# %% [markdown]
# <h1><center>CWD and Path</center></h1>

# %%
print("Current working dir:", os.getcwd())
# Out:
# Current working dir: /Users/ddi/git_hub/pros_project/src/notebooks

# %%
print("Initial Python path:", sys.path)

sys.path.append(os.getcwd().split('notebooks')[0])

print("\nPython path after append:", sys.path)
# Out:
# Initial Python path: ['/Library/Frameworks/Python.framework/Versions/3.10/lib/python310.zip', '/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10', '/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/lib-dynload', '', '/Users/ddi/python_venv/pros/lib/python3.10/site-packages']
#
# Python path after append: ['/Library/Frameworks/Python.framework/Versions/3.10/lib/python310.zip', '/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10', '/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/lib-dynload', '', '/Users/ddi/python_venv/pros/lib/python3.10/site-packages', '/Users/ddi/git_hub/pros_project/src/']

# %% [markdown]
# <h1><center>GLOBALS</center></h1>

# %%
MAJOR_VERSION = 1
MINOR_VERSION = 0
PATCH_VERSION = 0

IMPORT_PATH = '../data/imports/ai_student_impact_dataset.parquet'
EXPORT_PATH = f'../data/exports/selected_features_v{MAJOR_VERSION}.{MINOR_VERSION}.{PATCH_VERSION}.pkl'

# %% [markdown]
# <h1><center>Data Load</center></h1>

# %%
df = pd.read_parquet(IMPORT_PATH)

# %%
df
# Out:
#        Student_ID Major_Category Year_of_Study  Pre_Semester_GPA  \
# 0          100001     Humanities        Senior             2.418
# 1          100002        Medical        Junior             3.821
# 2          100003       Business      Freshman             3.398
# 3          100004       Business        Senior             3.789
# 4          100005           STEM     Sophomore             3.635
# ...           ...            ...           ...               ...
# 49995      149996       Business        Senior             2.899
# 49996      149997           STEM        Senior             2.870
# 49997      149998       Business        Senior             3.177
# 49998      149999       Business        Junior             3.398
# 49999      150000           Arts     Sophomore             3.242
#
#        Weekly_GenAI_Hours           Primary_Use_Case Prompt_Engineering_Skill  \
# 0                   23.31       Copywriting/Drafting                 Beginner
# ...

# %%
df.dtypes
# Out:
# Student_ID                      int64
# Major_Category                 object
# Year_of_Study                  object
# Pre_Semester_GPA              float64
# Weekly_GenAI_Hours            float64
# Primary_Use_Case               object
# Prompt_Engineering_Skill       object
# Tool_Diversity                  int64
# Paid_Subscription                bool
# Traditional_Study_Hours       float64
# Perceived_AI_Dependency         int64
# Institutional_Policy           object
# Anxiety_Level_During_Exams      int64
# Post_Semester_GPA             float64
# Skill_Retention_Score         float64
# Burnout_Risk_Level             object
# dtype: object

# %%
df['Major_Category'].unique()
# Out:
# array(['Humanities', 'Medical', 'Business', 'STEM', 'Arts'], dtype=object)

# %%
df['Year_of_Study'].unique()
# Out:
# array(['Senior', 'Junior', 'Freshman', 'Sophomore', 'Graduate'],
#       dtype=object)

# %%
df['Primary_Use_Case'].unique()
# Out:
# array(['Copywriting/Drafting', 'Ideation', 'Summarizing_Reading',
#        'Debugging/Troubleshooting', 'Direct_Answer_Generation'],
#       dtype=object)

# %%
df['Prompt_Engineering_Skill'].unique()
# Out:
# array(['Beginner', 'Advanced', 'Intermediate'], dtype=object)

# %%
df['Paid_Subscription'].unique()
# Out:
# array([ True, False])

# %%
df['Institutional_Policy'].unique()
# Out:
# array(['Allowed_With_Citation', 'Strict_Ban', 'Actively_Encouraged'],
#       dtype=object)

# %%
df['Burnout_Risk_Level'].unique()
# Out:
# array(['High', 'Low', 'Medium'], dtype=object)

# %% [markdown]
# <h1><center>Stratify Split</center></h1>

# %%
X_train, X_val_test, y_train, y_val_test = train_test_split(df.drop('Burnout_Risk_Level', axis=1),
                                                            df['Burnout_Risk_Level'],
                                                            test_size=0.1,
                                                            random_state=42,
                                                            stratify=df['Burnout_Risk_Level'])

X_val, X_test, y_val, y_test = train_test_split(X_val_test,
                                                y_val_test,
                                                test_size=0.5,
                                                random_state=42,
                                                stratify=y_val_test)

del X_val_test, y_val_test

# %%
print('\nUnique labels available:', df['Burnout_Risk_Level'].unique())

for label in df['Burnout_Risk_Level'].unique():

    assert round(y_train[y_train == label].shape[0]/y_train.shape[0], 2)\
        == round(y_val[y_val == label].shape[0]/y_val.shape[0], 2)\
        == round(y_test[y_test == label].shape[0]/y_test.shape[0], 2),\
        f"Stratify crition violated for label {label}. Check the split again!"
    
    print(f'\nStratify criterion satisfied. Imbalance ratio for label {label}:', round(y_train[y_train == label].shape[0]/y_train.shape[0], 2))
# Out:
# Unique labels available: ['High' 'Low' 'Medium']
#
# Stratify criterion satisfied. Imbalance ratio for label High: 0.25
#
# Stratify criterion satisfied. Imbalance ratio for label Low: 0.33
#
# Stratify criterion satisfied. Imbalance ratio for label Medium: 0.42

# %%
assert len(
              set(X_train['Student_ID'].unique())\
.intersection(set(X_val['Student_ID'].unique()))\
.intersection(set(X_test['Student_ID'].unique()))
) == 0,\
"Data Leackage between records from the split."

# %%
assert df['Student_ID'].value_counts().max() == 1,\
       "Presence of duplicate records. Check the data again!"

# %%
sudent_id_train = X_train['Student_ID']
X_train.drop('Student_ID', axis=1, inplace=True)

sudent_id_val = X_val['Student_ID']
X_val.drop('Student_ID', axis=1, inplace=True)

sudent_id_test = X_test['Student_ID']
X_test.drop('Student_ID', axis=1, inplace=True)

# %% [markdown]
# <h1><center>Labels' Encoding</center></h1>

# %%
label_encoder = LabelEncoder()

y_train, y_val, y_test = label_encoder.fit_transform(y_train),\
                         label_encoder.transform(y_val),\
                         label_encoder.transform(y_test)

# %% [markdown]
# <h1><center>One Hot Encoding</center></h1>

# %%
categories=['Major_Category', 'Year_of_Study',
            'Primary_Use_Case', 'Prompt_Engineering_Skill',
            'Paid_Subscription', 'Institutional_Policy']

feature_encoder = ColumnTransformer(
    transformers=[
        ("cat",
         OneHotEncoder(handle_unknown="ignore", sparse_output=False),
         categories)
    ],
    remainder="passthrough",
    n_jobs=-1
)

X_train, X_val, X_test = feature_encoder.fit_transform(X_train),\
                         feature_encoder.transform(X_val),\
                         feature_encoder.transform(X_test)

feature_names = feature_encoder.get_feature_names_out()

feature_names_fitlered = [col.split('cat__')[1] for col in feature_names if "cat__" in col]\
                       + [col.split('remainder__')[1] for col in feature_names if "remainder__" in col]

X_train, X_val, X_test = pd.DataFrame(X_train, columns=feature_names_fitlered),\
                         pd.DataFrame(X_val, columns=feature_names_fitlered),\
                         pd.DataFrame(X_test, columns=feature_names_fitlered)

# %% [markdown]
# <h1><center>Variance Threshold</center></h1>

# %%
variance_threshold = VarianceThreshold(threshold=1e-2)

X_train, X_val, X_test = variance_threshold.fit_transform(X_train),\
                         variance_threshold.transform(X_val),\
                         variance_threshold.transform(X_test)

features_names = variance_threshold.get_feature_names_out()

print('\nFiltered features with VarianceThreshol and threshold 1e-2:\n\n', set(feature_names_fitlered) - set(features_names))

X_train, X_val, X_test = pd.DataFrame(X_train, columns=features_names),\
                         pd.DataFrame(X_val, columns=features_names),\
                         pd.DataFrame(X_test, columns=features_names)
# Out:
# Filtered features with VarianceThreshol and threshold 1e-2:
#
#  set()

# %%
assert len(set(X_train.columns) - set(X_val.columns) - set(X_test.columns)) == 0,\
       "Feature mismatch between splits. Check VarianceThreshold again."

# %% [markdown]
# <h1><center>Boruta Filtration</center></h1>

# %%
features_before_boruta = X_train.columns

n_estimators = int(np.sqrt(len(X_train.columns)))

if int(np.sqrt(len(X_train.columns))) % 2 == 0:
    n_estimators += 1

brf = BalancedRandomForestClassifier(
    n_estimators=n_estimators,
    criterion='entropy',
    bootstrap=True,
    oob_score=True,
    sampling_strategy='majority',
    replacement=True,
    random_state=42,
    n_jobs=-1
)

boruta = BorutaPy(
    estimator=brf,
    n_estimators=n_estimators,
    perc=0.9,
    max_iter=100,
    random_state=42,
    verbose=2
)

boruta.fit(X_train.values, y_train)

selected_features_boruta = X_train.columns[boruta.support_]

print('\nDropped features from Boruta:\n\n', set(features_before_boruta) - set(X_train.columns[boruta.support_]))
# Out:
# /Users/ddi/python_venv/pros/lib/python3.10/site-packages/imblearn/ensemble/_forest.py:827: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# /Users/ddi/python_venv/pros/lib/python3.10/site-packages/imblearn/ensemble/_forest.py:827: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	31
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	31
# Rejected: 	0
# /Users/ddi/python_venv/pros/lib/python3.10/site-packages/imblearn/ensemble/_forest.py:827: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# ...

# %%
X_train, X_val, X_test = pd.DataFrame(boruta.transform(X_train.values), columns=selected_features_boruta),\
                         pd.DataFrame(boruta.transform(X_val.values), columns=selected_features_boruta),\
                         pd.DataFrame(boruta.transform(X_test.values), columns=selected_features_boruta)

# %%
assert len(set(X_train.columns) - set(X_val.columns) - set(X_test.columns)) == 0,\
       "Feature mismatch between splits. Check VarianceThreshold again."

# %% [markdown]
# <h1><center>Export to .pkl</center></h1>

# %%
with open(EXPORT_PATH, 'wb') as file:
    pickle.dump(selected_features_boruta, file)

# %%
# with open(EXPORT_PATH, 'rb') as file:
#     test = pickle.load(file)

# %%
#TODO the class
